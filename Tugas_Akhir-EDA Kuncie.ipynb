# %% [markdown]
# # Deskripsi Permasalahan

# %% [markdown]
# Membuat sebuah model untuk mengeksplorasi sebuah data untuk menemukan insight baru mengenai data customer yang berlangganan pada layanan telekomunikasi

# %% [markdown]
# # Metadata

# %% [markdown]
# Data yang digunakan adalah data dari source kuncie yang berisikan sebagai berikut :
# 1. terdiri dari 200 rows data --> identisikasi kolom yang berisikan data sesuai dengan ID Customer
# 2. baris CustomerID,Gender,Age,Payload(GB),.... dst --> Baris yang menampung banyaknya indikator mengenai data yang disajikan

# %% [markdown]
# # To Do

# %% [markdown]
# Membuat analisi baru dengan skema EDA (Exploration Data Analitics) dengan teknik Univariate Non-Graphical. dimana hal ini hanya akan terfokus kepada mengetahui nilai distribusi/data sampel yang mendasari dan melakukan pengamatan tentang populasi.

# %%
#import library Numpy
import numpy as np

#import library Pandas
import pandas as pd

# %%
pd.read_csv('Data_tugasakhir_Kuncie.csv') #mengambil data dari documents
# Out:
#      CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 0             1    Male   19                        15
# 1             2    Male   21                        15
# 2             3  Female   20                        16
# 3             4  Female   23                        16
# 4             5  Female   31                        17
# ..          ...     ...  ...                       ...
# 195         196  Female   35                       120
# 196         197  Female   45                       126
# 197         198    Male   32                       126
# 198         199    Male   32                       137
# 199         200    Male   30                       137
#
#      Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 0                          39                        9             2
# 1                          81                        5             2
# 2                           6                        5             1
# ...

# %%
df = pd.read_csv('Data_tugasakhir_Kuncie.csv') #membaca data dalam df

# %%
df
# Out:
#      CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 0             1    Male   19                        15
# 1             2    Male   21                        15
# 2             3  Female   20                        16
# 3             4  Female   23                        16
# 4             5  Female   31                        17
# ..          ...     ...  ...                       ...
# 195         196  Female   35                       120
# 196         197  Female   45                       126
# 197         198    Male   32                       126
# 198         199    Male   32                       137
# 199         200    Male   30                       137
#
#      Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 0                          39                        9             2
# 1                          81                        5             2
# 2                           6                        5             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                200 non-null    int64
#  1   Gender                    200 non-null    object
#  2   Age                       200 non-null    int64
#  3   Telco Spending (IDR 000)  200 non-null    int64
#  4   Purchasing power (1-100)  200 non-null    int64
#  5   Length of Stay (months)   200 non-null    int64
#  6   Payload (Gb)              200 non-null    int64
#  7   Voice (Minutes)           200 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 12.6+ KB

# %%
df.head(10) #informasi head 10 teratas dalam dataset
# Out:
#    CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 0           1    Male   19                        15
# 1           2    Male   21                        15
# 2           3  Female   20                        16
# 3           4  Female   23                        16
# 4           5  Female   31                        17
# 5           6  Female   22                        17
# 6           7  Female   35                        18
# 7           8  Female   23                        18
# 8           9    Male   64                        19
# 9          10  Female   30                        19
#
#    Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 0                        39                        9             2
# 1                        81                        5             2
# 2                         6                        5             1
# 3                        77                       10             1
# ...

# %%
df.describe() #informasi stastistik dataset
# Out:
#        CustomerID         Age  Telco Spending (IDR 000)  \
# count  200.000000  200.000000                200.000000
# mean   100.500000   38.850000                 60.560000
# std     57.879185   13.969007                 26.264721
# min      1.000000   18.000000                 15.000000
# 25%     50.750000   28.750000                 41.500000
# 50%    100.500000   36.000000                 61.500000
# 75%    150.250000   49.000000                 78.000000
# max    200.000000   70.000000                137.000000
#
#        Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# count                200.000000               200.000000    200.000000
# mean                  50.200000                26.025000      8.115000
# std                   25.823522                18.022442      5.304949
# min                    1.000000                 3.000000      1.000000
# 25%                   34.750000                 9.000000      4.000000
# ...

# %%
df.shape #dimensi dataset
# Out:
# (200, 8)

# %% [markdown]
# Terdapat 200 baris yang terdiri dari 8 kolom didalam dataset tersebut

# %%
df.dtypes #melihat type data pada setiap kolom
# Out:
# CustomerID                   int64
# Gender                      object
# Age                          int64
# Telco Spending (IDR 000)     int64
# Purchasing power (1-100)     int64
# Length of Stay (months)      int64
# Payload (Gb)                 int64
# Voice (Minutes)              int64
# dtype: object

# %% [markdown]
# Tipe data dari setiap kolom dalam dataset Data customer layanan telekomunikasi sudah sesuai

# %%
df.isna().sum() #Melakukan pengecekan missing value didalam dataset
# Out:
# CustomerID                  0
# Gender                      0
# Age                         0
# Telco Spending (IDR 000)    0
# Purchasing power (1-100)    0
# Length of Stay (months)     0
# Payload (Gb)                0
# Voice (Minutes)             0
# dtype: int64

# %% [markdown]
# Dataset Data Customer Layanan Telekomunikasi tidak memiliki Missing Value!

# %%
df.select_dtypes('object').describe()
#mendeskripsikan object terbanyak berdasarkan obj value Gender
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %% [markdown]
# Obyek dalam Gender yang terbanyak ternyata dimiliki oleh Female dengan total Frequency sebanyak 112 dari 200 data

# %%
counts = df['Gender'].value_counts()
print('Jumlah Pria:', counts['Male'])
print('Jumlah Wanita:', counts['Female'])

counts = df['Gender'].value_counts()
total_male_female = counts.sum()
print('Total Male and Female:', total_male_female)
# Out:
# Jumlah Pria: 88
# Jumlah Wanita: 112
# Total Male and Female: 200

# %% [markdown]
# Total Pelanggan/Customer pada layanan Telekomunikasi dikonfirmasi sesuai dengan perhitungan diatas. dengan jumlah pelanggan terbanyak dari kalangan Wanita.

# %% [markdown]
# ### Analisis Dasar Nilai-nilai pada setiap Parameter dalam Dataset

# %%
# kolom yang akan dihitung
column_list = ['Telco Spending (IDR 000)', 'Purchasing power (1-100)','Length of Stay (months)',
               'Payload (Gb)','Voice (Minutes)']

# mencari nilai mean, max, dan min pada kolom yang dipilih
mean_values = df[column_list].mean()
max_values = df[column_list].max()
min_values = df[column_list].min()

# menampilkan hasil
print('Mean :')
print(mean_values)
print('Max :')
print(max_values)
print('Min :')
print(min_values)
# Out:
# Mean :
# Telco Spending (IDR 000)    60.560
# Purchasing power (1-100)    50.200
# Length of Stay (months)     26.025
# Payload (Gb)                 8.115
# Voice (Minutes)             38.510
# dtype: float64
# Max :
# Telco Spending (IDR 000)    137
# Purchasing power (1-100)     99
# Length of Stay (months)      60
# Payload (Gb)                 20
# Voice (Minutes)              97
# dtype: int64
# Min :
# Telco Spending (IDR 000)    15
# Purchasing power (1-100)     1
# Length of Stay (months)      3
# Payload (Gb)                 1
# Voice (Minutes)              1
# dtype: int64

# %% [markdown]
# ### Analisis Data Berdasarkan Telco Spending in IDR from Highest to Lowest

# %%
#rewrite df value
df
# Out:
#      CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 0             1    Male   19                        15
# 1             2    Male   21                        15
# 2             3  Female   20                        16
# 3             4  Female   23                        16
# 4             5  Female   31                        17
# ..          ...     ...  ...                       ...
# 195         196  Female   35                       120
# 196         197  Female   45                       126
# 197         198    Male   32                       126
# 198         199    Male   32                       137
# 199         200    Male   30                       137
#
#      Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 0                          39                        9             2
# 1                          81                        5             2
# 2                           6                        5             1
# ...

# %% [markdown]
# Data diatas di tulis kembali untuk memastikan apakah urutan dalam tabel sudah sesuai dengan dataset utama yang akan dianalisis sesuai dengan penggunaan Telco spending

# %%
df.sort_values('Telco Spending (IDR 000)', ascending=True).head(10)
# Out:
#     CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 0            1    Male   19                        15
# 1            2    Male   21                        15
# 2            3  Female   20                        16
# 3            4  Female   23                        16
# 4            5  Female   31                        17
# 5            6  Female   22                        17
# 6            7  Female   35                        18
# 7            8  Female   23                        18
# 11          12  Female   35                        19
# 10          11    Male   67                        19
#
#     Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 0                         39                        9             2
# 1                         81                        5             2
# 2                          6                        5             1
# 3                         77                       10             1
# ...

# %%
column_list = ['Telco Spending (IDR 000)','Purchasing power (1-100)']
df[column_list].head(10)
# Out:
#    Telco Spending (IDR 000)  Purchasing power (1-100)
# 0                        15                        39
# 1                        15                        81
# 2                        16                         6
# 3                        16                        77
# 4                        17                        40
# 5                        17                        76
# 6                        18                         6
# 7                        18                        94
# 8                        19                         3
# 9                        19                        72

# %% [markdown]
# pada gambar dan keterangan diatas, merupakan data yang berisikan 10 baris pertama telco spending terendah yang dibandingkan dengan parameter indikator Purcasing Power (indikator kekuatan untuk membeli/transaksi)

# %%
df.sort_values('Telco Spending (IDR 000)', ascending=False).head(10)
# Out:
#      CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 199         200    Male   30                       137
# 198         199    Male   32                       137
# 197         198    Male   32                       126
# 196         197  Female   45                       126
# 195         196  Female   35                       120
# 194         195  Female   47                       120
# 193         194  Female   38                       113
# 192         193    Male   33                       113
# 190         191  Female   34                       103
# 189         190  Female   36                       103
#
#      Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 199                        83                       49            16
# 198                        18                       43            18
# 197                        74                       41            14
# 196                        28                       54            15
# ...

# %%
column_list = ['Telco Spending (IDR 000)', 'Purchasing power (1-100)']
df_sorted = df[column_list].sort_values(by=column_list, ascending=[False, False])
df_sorted.head(10)
# Out:
#      Telco Spending (IDR 000)  Purchasing power (1-100)
# 199                       137                        83
# 198                       137                        18
# 197                       126                        74
# 196                       126                        28
# 195                       120                        79
# 194                       120                        16
# 193                       113                        91
# 192                       113                         8
# 189                       103                        85
# 191                       103                        69

# %% [markdown]
# pada gambar dan keterangan diatas, merupakan data yang berisikan 10 baris pertama telco spending tertinggi yang dibandingkan dengan parameter indikator Purcasing Power (indikator kekuatan untuk membeli/transaksi)

# %%
variable_group = df.groupby(['Gender'],as_index=False)
variable_group['Telco Spending (IDR 000)'].mean().sort_values('Telco Spending (IDR 000)', 
                ascending=False)
# Out:
#    Gender  Telco Spending (IDR 000)
# 1    Male                 62.227273
# 0  Female                 59.250000

# %% [markdown]
# Berdasarkan data diatas, Telco spending rata-rata tertinggi dipegang oleh Customer dengan jenis kelamin (Gender) Laki-laki sebanyak Rp 62.227 dan Perempuan sebanyak Rp 59.250

# %% [markdown]
# #### Menganalisis nilai Minimum, Maksimum, dan Rata-rata pada Telco Spending dan Purcasing power Customer Layanan Telekomunikasi

# %% [markdown]
# Dibawah ini akan dilakukan analisis mengenai data range value terhadap Telco Spending dan Purcasing Power untuk mengetahui nilai Rata-rata, Nilai Maksimal, dan Nilai Minimal dari setiap Parameter data yang disajikan.

# %%
# kolom yang akan dihitung
column_list = ['Telco Spending (IDR 000)', 'Purchasing power (1-100)']

# mencari nilai mean, max, dan min pada kolom yang dipilih
mean_values = df[column_list].mean()
max_values = df[column_list].max()
min_values = df[column_list].min()

# menampilkan hasil
print('Mean :')
print(mean_values)
print('Max :')
print(max_values)
print('Min :')
print(min_values)
# Out:
# Mean :
# Telco Spending (IDR 000)    60.56
# Purchasing power (1-100)    50.20
# dtype: float64
# Max :
# Telco Spending (IDR 000)    137
# Purchasing power (1-100)     99
# dtype: int64
# Min :
# Telco Spending (IDR 000)    15
# Purchasing power (1-100)     1
# dtype: int64

# %% [markdown]
# ### Analisis Payload data (on GB) berdasarkan Rentang Usia (age) pengguna layanan

# %% [markdown]
# Dari sini kita ingin mengetahui dari range usia berapa saja pengguna terbanyak paket data (Payload) dalam satuan Gigabite

# %%
df.sort_values('Payload (Gb)', ascending=False).head(10)
# Out:
#      CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 191         192  Female   32                       103
# 186         187  Female   54                       101
# 175         176  Female   30                        88
# 156         157    Male   37                        78
# 161         162  Female   29                        79
# 169         170    Male   32                        87
# 176         177    Male   58                        88
# 185         186    Male   30                        99
# 163         164  Female   31                        81
# 177         178    Male   27                        88
#
#      Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 191                        69                       39            20
# 186                        24                       58            20
# 175                        86                       59            20
# 156                         1                       48            20
# ...

# %% [markdown]
# Mendapatkan data payload tertinggi yaitu 20GB, namun dari sini kita belum mengetahui sasaran pada umur berapa dengan pemakai tertinggi

# %%
column_list = ['Age', 'Payload (Gb)']
df_sorted = df[column_list].sort_values(by=column_list, ascending=[False, True])
df_sorted.head(10)
# Out:
#      Age  Payload (Gb)
# 60    70             5
# 70    70             7
# 57    69             3
# 67    68             3
# 90    68             9
# 108   68             9
# 10    67             1
# 62    67             2
# 82    67             6
# 102   67             6

# %% [markdown]
# berikut diatas merupakan data pemakai dengan usia tertua diangka 67 sd 70 tahun dengan jumlah Payload yang tertulis rata-rata kurang dari 10 GB

# %%
column_list = ['Payload (Gb)', 'Age']
df_sorted = df[column_list].sort_values(by=column_list, ascending=[False, False])
df_sorted.head(20)
# Out:
#      Payload (Gb)  Age
# 186            20   54
# 156            20   37
# 169            20   32
# 191            20   32
# 175            20   30
# 161            20   29
# 176            19   58
# 158            19   34
# 163            19   31
# 185            19   30
# 177            19   27
# 174            18   52
# 152            18   44
# 153            18   38
# 193            18   38
# 180            18   37
# 198            18   32
# 184            17   41
# 188            17   41
# 167            17   33

# %% [markdown]
# berikut diatas merupakan data pemakai dengan jumlah Payload (Gb) lebih dari 17 GB yang kurang lebih didominasi oleh usia produktif (range 26 sd 55 tahun)

# %%
variable_group = df.groupby(['Age'],as_index=False)
variable_group['Payload (Gb)'].mean().sort_values('Payload (Gb)', ascending=False).head(10)
# Out:
#     Age  Payload (Gb)
# 23   41     17.000000
# 19   37     14.333333
# 38   56     14.000000
# 26   44     13.500000
# 15   33     12.666667
# 12   30     12.285714
# 40   58     11.500000
# 14   32     11.454545
# 20   38     11.333333
# 16   34     11.000000

# %% [markdown]
# Dan diatas ini merupakan "cakupan" dari Rata-rata pemakai data Payload berdasarkan Genre umur (Age) yang didominasi pada usia produktif teraktif pada rentang usia 30 - 58, dan jumlah payload rata-rata tertinggi adalah 17GB

# %%
variable_group = df.groupby(['Gender'],as_index=False)
variable_group['Payload (Gb)'].mean().sort_values('Payload (Gb)', ascending=False)
# Out:
#    Gender  Payload (Gb)
# 1    Male      8.568182
# 0  Female      7.758929

# %% [markdown]
# Dari rata-rata Payload pemakaian, ternyata dari segmentasi customer dengan Gender (Jenis Kelamin) Laki-laki dengan pemakai rata-rata Payload tertinggi yaitu 8.5 GB, sedangkan Perempuan dengan payload rata-ratanya 7.7 GB

# %% [markdown]
# #### Analisis nilai Rata-rata, Nilai Maksimal, dan Nilai Minimal pada Usia (Age), dan Payload GB data customer pengguna layanan telekomunikasi

# %% [markdown]
# Berikut ini akan dilakukan analisis mengenai data range value terhadap Age/Usia dan Payload (satuan GB) untuk mengetahui nilai Rata-rata, Nilai Maksimal, dan Nilai Minimal dari setiap Parameter data yang disajikan.

# %%
# kolom yang akan dihitung
column_list = ['Age', 'Payload (Gb)']

# mencari nilai mean, max, dan min pada kolom yang dipilih
mean_values = df[column_list].mean()
max_values = df[column_list].max()
min_values = df[column_list].min()

# menampilkan hasil
print('Mean :')
print(mean_values)
print('Max :')
print(max_values)
print('Min :')
print(min_values)
# Out:
# Mean :
# Age             38.850
# Payload (Gb)     8.115
# dtype: float64
# Max :
# Age             70
# Payload (Gb)    20
# dtype: int64
# Min :
# Age             18
# Payload (Gb)     1
# dtype: int64

# %% [markdown]
# #### Analisis Lama pemakaian (dalam bulan) berdasarkan Gender customer

# %%
column_list = ['Gender','Length of Stay (months)']
df[column_list]
# Out:
#      Gender  Length of Stay (months)
# 0      Male                        9
# 1      Male                        5
# 2    Female                        5
# 3    Female                       10
# 4    Female                       11
# ..      ...                      ...
# 195  Female                       49
# 196  Female                       54
# 197    Male                       41
# 198    Male                       43
# 199    Male                       49
#
# [200 rows x 2 columns]

# %%
column_list = ['Length of Stay (months)']
df[column_list].sum()
# Out:
# Length of Stay (months)    5205
# dtype: int64

# %% [markdown]
# Menghitung Total jumlah Bulan yang dihabiskan oleh semua customer

# %%
variable_group = df.groupby('Gender',as_index=False)
variable_group['Length of Stay (months)'].sum()
# Out:
#    Gender  Length of Stay (months)
# 0  Female                     2807
# 1    Male                     2398

# %%
variable_group = df.groupby('Gender',as_index=False)
variable_group['Length of Stay (months)'].mean()
# Out:
#    Gender  Length of Stay (months)
# 0  Female                  25.0625
# 1    Male                  27.2500

# %% [markdown]
# Menghitung Total jumlah Bulan yang dihabiskan oleh customer (dalam bulan) berdasarkan jenis kelamin. dengan jumlah total terbanyak oleh Perempuan. namun untuk rata-rata bulanan yang dihabiskan untuk menjadi pelanggan loyal adalah 27 Bulan berasal dari kalangan Laki-laki

# %% [markdown]
# ## K-Means Cluster Analysist

# %% [markdown]
# K-means clustering dibuat untuk mengetahui data berdasarkan unsupervised modeling dengan penerapan pada elbow method yang akan dilakukan untuk mengetahui kluster-kluster data yang akan tervisualisasi berdasarkan plot-plot tersebut

# %% [markdown]
# #### Masukan import Library Pythonnya dahulu

# %%
#import library pandas
import pandas as pd

#import library NumPy
import numpy as np

#import Plot Math Library
import matplotlib.pyplot as plt

#import Seaborn >> KMeans calculating
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %matplotlib inline

# %% [markdown]
# #### Masukan data Customer yang akan dianalisis. Studi kasus Data Customer pada Layanan Telekomunikasi

# %%
raw_data = pd.read_csv('Data_tugasakhir_Kuncie.csv')
raw_data.head(10)
# Out:
#    CustomerID  Gender  Age  Telco Spending (IDR 000)  \
# 0           1    Male   19                        15
# 1           2    Male   21                        15
# 2           3  Female   20                        16
# 3           4  Female   23                        16
# 4           5  Female   31                        17
# 5           6  Female   22                        17
# 6           7  Female   35                        18
# 7           8  Female   23                        18
# 8           9    Male   64                        19
# 9          10  Female   30                        19
#
#    Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# 0                        39                        9             2
# 1                        81                        5             2
# 2                         6                        5             1
# 3                        77                       10             1
# ...

# %% [markdown]
# #### Membuat Index pada Gender, dan me-replace isi nya

# %%
data = raw_data.set_index(['CustomerID'])

# %%
mapping = {"Gender" : {"Male":0, "Female":1}}
data.replace(mapping, inplace=True)

# %%
data.head(10)
# Out:
#             Gender  Age  Telco Spending (IDR 000)  Purchasing power (1-100)  \
# CustomerID
# 1                0   19                        15                        39
# 2                0   21                        15                        81
# 3                1   20                        16                         6
# 4                1   23                        16                        77
# 5                1   31                        17                        40
# 6                1   22                        17                        76
# 7                1   35                        18                         6
# 8                1   23                        18                        94
# 9                0   64                        19                         3
# 10               1   30                        19                        72
#
#             Length of Stay (months)  Payload (Gb)  Voice (Minutes)
# CustomerID
# ...

# %%
data.describe()
# Out:
#            Gender         Age  Telco Spending (IDR 000)  \
# count  200.000000  200.000000                200.000000
# mean     0.560000   38.850000                 60.560000
# std      0.497633   13.969007                 26.264721
# min      0.000000   18.000000                 15.000000
# 25%      0.000000   28.750000                 41.500000
# 50%      1.000000   36.000000                 61.500000
# 75%      1.000000   49.000000                 78.000000
# max      1.000000   70.000000                137.000000
#
#        Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# count                200.000000               200.000000    200.000000
# mean                  50.200000                26.025000      8.115000
# std                   25.823522                18.022442      5.304949
# min                    1.000000                 3.000000      1.000000
# 25%                   34.750000                 9.000000      4.000000
# ...

# %%
data.nunique()
# Out:
# Gender                       2
# Age                         51
# Telco Spending (IDR 000)    64
# Purchasing power (1-100)    84
# Length of Stay (months)     55
# Payload (Gb)                20
# Voice (Minutes)             76
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Gender                      0
# Age                         0
# Telco Spending (IDR 000)    0
# Purchasing power (1-100)    0
# Length of Stay (months)     0
# Payload (Gb)                0
# Voice (Minutes)             0
# dtype: int64

# %% [markdown]
# ### Merancang Plotting Data

# %%
sns.pairplot(data)

# %% [markdown]
# ### Merancang data berdasarkan Elbow Method untuk mengidentifikasi grafik pada sistem clustering

# %%
#Merancang Elbow Method grafik dengan data full
# Initialize empty list of cost function values
wcss = []

# Create K-means models for different values of K
for i in range(2, 11):
    kmeans = KMeans(i)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)  # inertia_ attribute gives the SSE value
    
# Plot the elbow graph
plt.plot(range(2, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method Graph')
plt.show()

# %% [markdown]
# ### Skor Siluet untuk mengidentifikasi angka pada kluster

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

sil = []
#Angka kluster dalam jangkauan 1-20
K = range(2, 11)
for n in K:
    algorithm = (KMeans(n_clusters = n) )
    algorithm.fit(data)
    labels = algorithm.labels_
    sil.append(silhouette_score(data, labels, metric = 'euclidean'))

# %%
sil
# Out:
# [0.43607351956554863,
#  0.43507762296553465,
#  0.364400347451753,
#  0.3949716795953968,
#  0.36644410519752363,
#  0.3559485690454183,
#  0.367030274697667,
#  0.36546350644088677,
#  0.3468950891367295]

# %% [markdown]
# Nilai ideal untuk menganalisis prediksi, dapat disimpulkan terbaik posisi range antara 4 atau 5

# %% [markdown]
# ### Graph skor siluete sesuai dengan klustering

# %% [markdown]
# setelah didapatkan skoring siluete pada posisi range terbaik antara 4 atau 5. maka pembuktian selanjutnya yaitu dengan ditampilkan grafik skoring siluete apakah posisi yang dipilih telah pas ataupun tidak. sesuai dari analisis skoring tertinggi diantara nilai-nilai prediksi yang telah diberikan

# %%
# Plot the silhouette scores
import matplotlib.pyplot as plt
plt.plot(K, sil)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette Scores for K-means Clustering')
plt.show()

# %% [markdown]
# ### Analisis perbandingan antara Length of Stay dengan Telco Spending

# %% [markdown]
# Analisis Telco Spending dengan Length of Stay bertujuan untuk mengetahui cluster dari jumlah spending customer berdasarkan tingkat loyalitas yang didukung dengan jumlah rata-rata usia customers dan untuk mengetahui tingkatan customer behaviour terhadap produk yang ditawarkan oleh Penyedia Jasa Layanan Telekomunikasi.

# %%
kmeans = KMeans(4)
kmeans.fit(data)
clusters = data.copy()
clusters['prediction'] = kmeans.fit_predict(clusters)
clusters.head(10)
# Out:
#             Gender  Age  Telco Spending (IDR 000)  Purchasing power (1-100)  \
# CustomerID
# 1                0   19                        15                        39
# 2                0   21                        15                        81
# 3                1   20                        16                         6
# 4                1   23                        16                        77
# 5                1   31                        17                        40
# 6                1   22                        17                        76
# 7                1   35                        18                         6
# 8                1   23                        18                        94
# 9                0   64                        19                         3
# 10               1   30                        19                        72
#
#             Length of Stay (months)  Payload (Gb)  Voice (Minutes)  prediction
# CustomerID
# ...

# %%
plt.scatter(data['Telco Spending (IDR 000)'],data['Length of Stay (months)'], c= clusters['prediction'], cmap='rainbow')
plt.xlabel('Telco Spending (IDR 000)')
plt.ylabel('Length of Stay (months)')
plt.title('K-means Clustering Telco Spending x Length Stay')
# Out:
# Text(0.5, 1.0, 'K-means Clustering Telco Spending x Length Stay')

# %% [markdown]
# terlihat grafik persebaran kluster diatas terdapat 4 klustering yang terbagi setelah plot disusun antara perbandingan dari data telcospending dan length of stay

# %% [markdown]
# ### Mengetahui Rata-rata nilai pada setiap warna clustering

# %%
clusters.groupby('prediction').mean()
# Out:
#               Gender        Age  Telco Spending (IDR 000)  \
# prediction
# 0           0.566667  32.033333                 91.033333
# 1           0.542857  40.971429                 62.428571
# 2           0.500000  41.833333                 91.033333
# 3           0.600000  38.371429                 32.571429
#
#             Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# prediction
# 0                          82.866667                48.666667     14.366667
# 1                          49.585714                24.500000      7.957143
# 2                          18.933333                50.400000     14.566667
# 3                          50.214286                 7.400000      2.828571
#
#             Voice (Minutes)
# prediction
# 0                 75.433333
# 1                 34.114286
# 2                 76.300000
# 3                 10.885714

# %%
# Group the data by 'prediction' column and calculate the mean of each column
grouped_data = clusters.groupby('prediction').mean()

# Create a new table with selected columns
new_table = grouped_data[['Age', 'Telco Spending (IDR 000)', 'Length of Stay (months)']]

# Print the new table
print(new_table)
# Out:
#                   Age  Telco Spending (IDR 000)  Length of Stay (months)
# prediction
# 0           32.033333                 91.033333                48.666667
# 1           40.971429                 62.428571                24.500000
# 2           41.833333                 91.033333                50.400000
# 3           38.371429                 32.571429                 7.400000

# %% [markdown]
# ### Menyimpan data dan Hasil visualisasi

# %%
# Save the new table to Excel file
new_table.to_excel('TelcoSpendingxLengthstayinAge.xlsx', index=False)

# %%
plt.scatter(data['Telco Spending (IDR 000)'],data['Length of Stay (months)'], c= clusters['prediction'], cmap='rainbow')
plt.xlabel('Telco Spending (IDR 000)')
plt.ylabel('Length of Stay (months)')
plt.title('K-means Clustering Telco Spending x Length Stay')

# Save the plot as a PNG image
plt.savefig('scatterplot_TelcoSpendingxLengthstayinAge.png')

# %% [markdown]
# ### Analisis perbandingan antara Usia dengan Kemampuan Payload data

# %% [markdown]
# Analisis antara kemampuan daya streaming Payload (penggunaan berdasarkan paket data dalam Gigabite) dengan usia customer dilakukan untuk mengetahui cluster pada rentang usia berapa sajakah pengguna dengan jumlah kuota paket data tertinggi dan terendah

# %%
kmeans = KMeans(5)
kmeans.fit(data)
clusters = data.copy()
clusters['prediction'] = kmeans.fit_predict(clusters)
clusters.head(10)
# Out:
#             Gender  Age  Telco Spending (IDR 000)  Purchasing power (1-100)  \
# CustomerID
# 1                0   19                        15                        39
# 2                0   21                        15                        81
# 3                1   20                        16                         6
# 4                1   23                        16                        77
# 5                1   31                        17                        40
# 6                1   22                        17                        76
# 7                1   35                        18                         6
# 8                1   23                        18                        94
# 9                0   64                        19                         3
# 10               1   30                        19                        72
#
#             Length of Stay (months)  Payload (Gb)  Voice (Minutes)  prediction
# CustomerID
# ...

# %%
plt.scatter(data['Age'], data['Payload (Gb)'], c= clusters['prediction'], cmap='rainbow')
plt.xlabel('Age')
plt.ylabel('Payload (Gb)')
plt.title('K-means Clustering Payload x Age')
# Out:
# Text(0.5, 1.0, 'K-means Clustering Payload x Age')

# %% [markdown]
# terlihat grafik persebaran kluster diatas terdapat 5 klustering yang terbagi setelah plot disusun antara perbandingan dari data Payload dan Usia

# %% [markdown]
# ### Mengetahui Rata-rata nilai pada setiap warna clustering

# %%
clusters.groupby('prediction').mean()
# Out:
#               Gender        Age  Telco Spending (IDR 000)  \
# prediction
# 0           0.542857  40.971429                 62.428571
# 1           0.566667  32.033333                 91.033333
# 2           0.634146  47.609756                 34.195122
# 3           0.500000  41.833333                 91.033333
# 4           0.551724  25.310345                 30.275862
#
#             Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# prediction
# 0                          49.585714                24.500000      7.957143
# 1                          82.866667                48.666667     14.366667
# 2                          33.414634                 7.146341      2.804878
# 3                          18.933333                50.400000     14.566667
# 4                          73.965517                 7.758621      2.862069
#
#             Voice (Minutes)
# prediction
# 0                 34.114286
# 1                 75.433333
# 2                 10.317073
# ...

# %%
# Group the data by 'prediction' column and calculate the mean of each column
grouped_data = clusters.groupby('prediction').mean()

# Create a new table with selected columns
new_table = grouped_data[['Age', 'Payload (Gb)']]

# Print the new table
print(new_table)
# Out:
#                   Age  Payload (Gb)
# prediction
# 0           40.971429      7.957143
# 1           32.033333     14.366667
# 2           47.609756      2.804878
# 3           41.833333     14.566667
# 4           25.310345      2.862069

# %% [markdown]
# ### Menyimpan data dan Hasil visualisasi

# %%
# Save the new table to Excel file
new_table.to_excel('PayloadinAge.xlsx', index=False)

# %%
plt.scatter(data['Age'], data['Payload (Gb)'], c= clusters['prediction'], cmap='rainbow')
plt.xlabel('Age')
plt.ylabel('Payload (Gb)')
plt.title('K-means Clustering Payload x Age')

# Save the plot as a PNG image
plt.savefig('scatterplot_PayloadinAge.png')

# %% [markdown]
# ### Analisis perbandingan antara penggunaan Payload dan Voice Call

# %% [markdown]
# Analisis antara penggunaan Payload dengan Voice call dilakukan untuk mengetahui klustering penggunaan Payload (Paket Data) dengan Voice call berdasarkan rentang rata-rata usia customer

# %%
kmeans = KMeans(4)
kmeans.fit(data)
clusters = data.copy()
clusters['prediction'] = kmeans.fit_predict(clusters)
clusters.head(10)
# Out:
#             Gender  Age  Telco Spending (IDR 000)  Purchasing power (1-100)  \
# CustomerID
# 1                0   19                        15                        39
# 2                0   21                        15                        81
# 3                1   20                        16                         6
# 4                1   23                        16                        77
# 5                1   31                        17                        40
# 6                1   22                        17                        76
# 7                1   35                        18                         6
# 8                1   23                        18                        94
# 9                0   64                        19                         3
# 10               1   30                        19                        72
#
#             Length of Stay (months)  Payload (Gb)  Voice (Minutes)  prediction
# CustomerID
# ...

# %%
plt.scatter(data['Voice (Minutes)'], data['Payload (Gb)'], c= clusters['prediction'], cmap='rainbow')
plt.xlabel('Voice (Minutes)')
plt.ylabel('Payload (Gb)')
plt.title('K-means Clustering Payload x Voice (Minutes)')
# Out:
# Text(0.5, 1.0, 'K-means Clustering Payload x Voice (Minutes)')

# %% [markdown]
# terlihat grafik persebaran kluster diatas terdapat 4 klustering yang terbagi setelah plot disusun antara perbandingan dari data pengguna Payload dan Voice call

# %% [markdown]
# ### Mengetahui Rata-rata nilai pada setiap warna clustering

# %%
clusters.groupby('prediction').mean()
# Out:
#               Gender        Age  Telco Spending (IDR 000)  \
# prediction
# 0           0.542857  40.971429                 62.428571
# 1           0.566667  32.033333                 91.033333
# 2           0.600000  38.371429                 32.571429
# 3           0.500000  41.833333                 91.033333
#
#             Purchasing power (1-100)  Length of Stay (months)  Payload (Gb)  \
# prediction
# 0                          49.585714                24.500000      7.957143
# 1                          82.866667                48.666667     14.366667
# 2                          50.214286                 7.400000      2.828571
# 3                          18.933333                50.400000     14.566667
#
#             Voice (Minutes)
# prediction
# 0                 34.114286
# 1                 75.433333
# 2                 10.885714
# 3                 76.300000

# %%
# Group the data by 'prediction' column and calculate the mean of each column
grouped_data = clusters.groupby('prediction').mean()

# Create a new table with selected columns
new_table = grouped_data[['Age', 'Payload (Gb)', 'Voice (Minutes)']]

# Print the new table
print(new_table)
# Out:
#                   Age  Payload (Gb)  Voice (Minutes)
# prediction
# 0           40.971429      7.957143        34.114286
# 1           32.033333     14.366667        75.433333
# 2           38.371429      2.828571        10.885714
# 3           41.833333     14.566667        76.300000

# %% [markdown]
# ### Menyimpan data dan hasil visualisasi

# %%
# Save the new table to Excel file
new_table.to_excel('PayloadxVoiceinAge.xlsx', index=False)

# %%
plt.scatter(data['Voice (Minutes)'], data['Payload (Gb)'], c= clusters['prediction'], cmap='rainbow')
plt.xlabel('Voice (Minutes)')
plt.ylabel('Payload (Gb)')
plt.title('K-means Clustering Payload x Voice (Minutes)')

# Save the plot as a PNG image
plt.savefig('scatterplot_PayloadxVoiceinAge.png')
